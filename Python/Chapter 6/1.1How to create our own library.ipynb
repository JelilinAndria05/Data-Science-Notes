# %% [markdown]
# # MODULE 1
#
# 1. How to create our own module & import it like pandas library
# 2. Creating modules Vs purpose of oops
# 3. How to create class, objects & inheritance methods & its real-time purpose

# %% [markdown]
# ## 1. How to create our own module & import it like pandas library

# %%
def addition(a,b):
    return a+b
def substraction(a,b):
    return a-b
def multiplication(a,b):
    return a*b                      ## intha function na mattum vera note la potu vaisikulaam

# %% [markdown]
# ### *Difference between return & print*
#
# * Return - Import the original data when the function is called return
# * print  - It won't impact the original data, but just print

# %% [markdown]
# ### *Terminology Alert:-*
#
# * Parameters - while creating the function, you create parameters.
# * Attributes - while calling the function, you pass arguments.
