# %% [markdown]
# # NOTE
#
# 1. Univariate charts can include more than one feature
# 2. Bivariate charts can nclude more than two features

# %%
import pandas as pd
mtcars_data = pd.read_csv("mtcars.csv")

# %%
import seaborn as sns

# %%
sns.histplot(mtcars_data, x= "mpg", hue= "am", multiple= "stack")
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>
